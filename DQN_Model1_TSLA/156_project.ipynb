# %% [markdown]
# ## Reinforcement Learning

# %% [markdown]
# We first write a function to create a data frame including stock price data for the past 5 years including open, close, low, and high prices. We also add columns for the difference between open and close prices, the difference between high and low prices, and whether that month is the end of a quarter to predict the buy or not for investors.

# %%
import keras
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense
from tensorflow.keras.optimizers.legacy import Adam
import tensorflow as tf

import yfinance as yf
import math
import numpy as np
import pandas as pd
import random
from collections import deque

# %%
def create_price_df(ticker):
    """
    ticker: the chosen company stock

    Return: returns a dataframe of a company's stock price data and features we want to use in machine learning model
    """
    price_df = price_df=yf.download(tickers = ticker, period = "5y", interval = "1d",
    prepost = False, repair = True)
    price_df["date"]=price_df.index
    price_df.reset_index()
    price_df["Date"] = price_df["date"].transform(lambda x: x.date())
    price_df["Date"] = price_df["Date"].transform(lambda x: str(x))
    price_df = price_df.drop(['date'],axis=1)
    splitted=price_df['Date'].str.split('-',expand = True)
    price_df['day'] = splitted[2].astype('int')
    price_df['month'] = splitted[1].astype('int')
    price_df['year'] = splitted[0].astype('int')
    price_df['is_quarter_end']=np.where(price_df['month']%3 == 0,1,0)
    price_df['open-close']  = price_df['Open'] - price_df['Close']
    price_df['low-high']  = price_df['Low'] - price_df['High']
    price_df['target'] = np.where(price_df['Close'].shift(-1) > price_df['Close'], 1, 0)
    #if the close price of the previous day is higher than today's close price, then the investor will buy the stock
    return price_df

# %%
# ticker is basically a abbreviation for a company stock.
ticker=input("Please enter your ticker: ")
price_df = create_price_df(ticker = ticker)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
price_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-03-12   19.099333   19.204666   18.737333   18.890667   18.890667
# 2019-03-13   18.926666   19.466000   18.846666   19.264000   19.264000
# 2019-03-14   19.496668   19.692667   19.219334   19.330667   19.330667
# 2019-03-15   18.900667   18.914667   18.293333   18.362000   18.362000
# 2019-03-18   18.400000   18.536667   17.820000   17.966000   17.966000
# ...                ...         ...         ...         ...         ...
# 2024-03-06  179.990005  181.580002  173.699997  176.539993  176.539993
# 2024-03-07  174.350006  180.039993  173.699997  178.649994  178.649994
# 2024-03-08  181.500000  182.729996  174.699997  175.339996  175.339996
# 2024-03-11  175.449997  182.869995  174.800003  177.770004  177.770004
# 2024-03-12  177.770004  179.080002  172.410095  177.970001  177.970001
#
#                Volume  Repaired?        Date  day  month  year  \
# Date
# 2019-03-12  112561500      False  2019-03-12   12      3  2019
# 2019-03-13  102670500      False  2019-03-13   13      3  2019
# 2019-03-14  106551000      False  2019-03-14   14      3  2019
# 2019-03-15  221782500      False  2019-03-15   15      3  2019
# 2019-03-18  154215000      False  2019-03-18   18      3  2019
# ...               ...        ...         ...  ...    ...   ...
# 2024-03-06  107920900      False  2024-03-06    6      3  2024
# 2024-03-07  102129000      False  2024-03-07    7      3  2024
# 2024-03-08   85315300      False  2024-03-08    8      3  2024
# 2024-03-11   85211900      False  2024-03-11   11      3  2024
# 2024-03-12   68229220      False  2024-03-12   12      3  2024
#
#             is_quarter_end  open-close  low-high  target
# Date
# 2019-03-12               1    0.208666 -0.467333       1
# 2019-03-13               1   -0.337334 -0.619333       1
# 2019-03-14               1    0.166000 -0.473333       0
# 2019-03-15               1    0.538668 -0.621334       0
# 2019-03-18               1    0.434000 -0.716667       0
# ...                    ...         ...       ...     ...
# 2024-03-06               1    3.450012 -7.880005       1
# 2024-03-07               1   -4.299988 -6.339996       0
# 2024-03-08               1    6.160004 -8.029999       1
# 2024-03-11               1   -2.320007 -8.069992       1
# 2024-03-12               1   -0.199997 -6.669907       0
#
# [1260 rows x 15 columns]

# %% [markdown]
# The code sets up a reinforcement learning agent with a neural network model that learns to make decisions (buying, selling, or sitting) in a stock trading environment. The agent learns from its experiences using the Q-learning algorithm and improves its performance over time through repeated interactions with the environment.

# %% [markdown]
# The act method determines the agent's action based on the current state. The neural network model predicts the Q-values for the current state. These predicted Q-values correspond to the estimated future rewards for each possible action the agent can take. The agent then chooses the action with the highest predicted Q-value, unless it is in evaluation mode (is_eval=True) or randomly selected due to exploration.

# %% [markdown]
# The expReplay method implements experience replay. It samples a batch of experiences from the memory and updates the model's weights based on the Bellman equation, which estimates the optimal action-value function (Q-value).

# %%
# Agent class
class Agent:
    def __init__(self, state_size, is_eval=False, model_name=""):
        """Initialize Agent class:
        Define static variables like gamma, epsilon, epsilon_min, and epsilon_decay to
          manage the trade-off between exploration and exploitation in the decision-making process.
        Gamma (discount factor) influences how future rewards are valued.
        Epsilon controls the rate of exploration versus exploitation,
          with epsilon_min and epsilon_decay dictating the minimum exploration rate and how quickly exploration decreases, respectively.
        These parameters are crucial for the agent's strategy in buying and selling stocks,
          ensuring a balance between exploiting known strategies and exploring new possibilities."""

        self.state_size = state_size
          # length of the historical sequence of stock prices that the agent uses as its input state size, measured in trading days
        self.action_size = 3
          # 3 actions: sit, buy, sell
        self.memory = deque(maxlen=1000)
          # internal memory with maximum length 1000, used for experience replay;
          # allows the agent to learn from past experiences.
        self.inventory = []
          # keep track of the stocks currently held by the agent
          # A "buy" action adds the stock to the inventory, while a "sell" action removes it.
        self.model_name = model_name
          # name of the model
        self.is_eval = is_eval
          # evaluation flag
        self.gamma = 0.95
          # discount rate for the next state; determines the present value of future rewards;
          # As γ is closer to 0, the agent prioritizes immediate rewards more heavily, focusing on short-term gains;
          # As γ approaches 1, the agent places greater value on future rewards, encouraging strategies with more
          # pay-off in the long run.
        self.epsilon = 1.0
          # exploration rate; used to implement the ϵ-greedy strategy, where the agent randomly explores the
          # environment with a probability of ϵ and exploits its current knowledge with a probability of 1−ϵ;
          # If epsilon is set to 0, we never explore but always exploit the knowledge we already have.
          # On the contrary, a higher value of ϵ (closer to 1) is used to encourage exploration of the environment.
        self.epsilon_min = 0.01
          # minimum exploration probability; sets the lower bound of ϵ;
          # ensure the agent continues to explore the environment to a certain extent even after extensive training.
        self.epsilon_decay = 0.995
          # exponential decay rate for exploration prob; controls the rate at which ϵ decreases over time;
          # gradually shifting the agent's strategy from exploration towards exploitation.
        self.model = load_model(model_name) if is_eval else self._model()
          # load model if is_eval is true, else create a new model

    def _model(self):
        """Neural Network Model"""
        # # create a neural network model with 3 hidden layers, to predict the reward value of actions.
        # model = Sequential()
        # model.add(Dense(units=64, input_dim=self.state_size, activation="relu"))
        # model.add(Dense(units=32, activation="relu"))
        # model.add(Dense(units=8, activation="relu"))
        # model.add(Dense(self.action_size, activation="linear"))
        # model.compile(loss="mse", optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])
        # # mean squared error loss, adam optimizer with learning rate of 0.001
        
        model = tf.keras.Sequential([
            # Input layer: No need to explicitly set an input layer. The input shape will be determined in the first Dense layer.
            # First Dense layer with ReLU activation. The `input_dim` parameter specifies the size of the input layer.
            tf.keras.layers.Dense(units=16, activation='relu', input_dim=self.state_size),

            # Second Dense layer with ReLU activation.
            tf.keras.layers.Dense(units=8, activation='relu'),

            # Output layer with linear activation, since we're predicting Q-values which are continuous.
            tf.keras.layers.Dense(units=self.action_size, activation='linear')
        ])

        # Compile the model. For a Q-learning model, we typically use the Mean Squared Error (MSE) loss and an optimizer like Adam.
        model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001),
                      loss='mse',
                      metrics=['accuracy'])  # Metrics are optional and may not be very meaningful in this context.
        return model

    def act(self, state):
        """Agent will act upon the current state:
        defines how the agent chooses an action based on the current state it is in."""
        # Exploration:
        if not self.is_eval and random.random()<= self.epsilon:
            # Check if the agent is not in evaluation mode and
            # if a randomly generated number between 0 and 1 is within the boundary.
            # If both conditions are met, the agent is in the exploration phase,
            # and an action is chosen randomly from the available action space.
            return random.randrange(self.action_size)
        # Exploitation:
            # If the agent decides not to explore, it enters the exploitation phase;
            # it chooses the action that it believes will yield the highest reward based on current knowledge.
        options = self.model.predict(state)
            # given the current state, use the agent's NN model to predict the reward value of each possible action.
        return np.argmax(options[0])
            # select the action with the highest predicted reward.

    def expReplay(self, batch_size):
        """Experience Replay
        Involves storing past experiences (state, action, reward, next_state, done) in a memory
        buffer and later randomly sampling a mini-batch of these experiences to train the model."""

        minibatch = random.sample(self.memory, batch_size)
        states = np.array([i[0] for i in minibatch])
        actions = np.array([i[1] for i in minibatch])
        rewards = np.array([i[2] for i in minibatch])
        next_states = np.array([i[3] for i in minibatch])
        dones = np.array([i[4] for i in minibatch])

        states = np.squeeze(states)
        next_states = np.squeeze(next_states)

        targets = rewards + self.gamma*(np.amax(self.model.predict_on_batch(next_states), axis=1))*(1-dones)
        targets_full = self.model.predict_on_batch(states)

        ind = np.array([i for i in range(batch_size)])
        targets_full[[ind], [actions]] = targets

        self.model.fit(states, targets_full, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
def formatPrice(n):
    """Format price"""
    # format price as $x.xx
    return("-$ " if n<0 else "$ ")+"{0:.2f}".format(abs(n))

def sigmoid(x):
    """Sigmoid function"""
    # sigmoid "squashing" function to interval [0,1], for normalization purpose
    return 1/(1+math.exp(-x))

def getState(data, t, n):
    """Get state
    data: A list or array containing the historical data points (e.g., stock prices).
    t: The current timestep for which the state is being generated.
    n: The window size, indicating how many timesteps back the state should consider."""
    d = t - n + 1
      # Calculate the starting index of the data block that will be used to generate the state.
      # d identifies the earliest timestep in the window.

    block = data[d:t + 1] if d >= 0 else -d * [data[0]] + data[0:t + 1]
      # Extract the relevant block of data for the state.
      # If d is non-negative, it directly slices the data array from d to t, inclusive.
      # Else(the window extends beyond the start of the available data), it pads the
      # beginning of the block with the value at data[0]. The number of times data[0] is
      # repeated corresponds to -d, ensuring the resulting block has a length of n.

    res = []
      # list to store the price changes within the window.
    for i in range(n - 1):
        res.append(sigmoid(block[i + 1] - block[i]))
        # calculate price change between successive timesteps and apply the sigmoid function to each change.

    # return array of price changes
    return np.array([res])

# %% [markdown]
# The code below performs the training loop for the reinforcement learning agent in the stock trading environment. It interacts with the environment, executes actions, and updates the agent's neural network model based on the observed rewards.

# %% [markdown]
# One thing to note is the agent's memory. The agent's memory is used for experience replay, which is a technique in reinforcement learning that helps improve the agent's learning efficiency and stability. During the training process, the agent samples a batch of experiences from its memory and uses them to update its model through a process called experience replay. This helps the agent learn from a diverse set of experiences and reduces the correlation between consecutive samples.

# %%
import sys
# window_size = input()
# episode_count = input()
window_size = 6
episode_count = 20

window_size = int(window_size)
  # Window size represents the length of historical sequence of stock prices that the agent uses as its input state.
  # This allows the agent to consider patterns over a specified number of previous time steps when making decisions.
  # By setting a larger window size, the agent can capture more historical price patterns and possibly make more informed decisions.
episode_count = int(episode_count)
  # The number of episodes for which the agent will be trained.
  # Each episode represents a complete sequence of decisions (trading actions) from start to finish based on the data.

agent = Agent(window_size)
  # Initialize agent
  # Recall that def __init__(self, state_size, is_eval=False, model_name="")

data=list(price_df['Close'][0:1000])
  # Get the stock data
  # specifically the closing prices, which the agent uses to learn trading strategies.

l = len(data) - 1  # data length
batch_size = 32    # batch size

# Initialize episode information list
episode_info_list = []
scores = []
# Training Loop:
for i_episode in range(episode_count+1):
    print("Episode " + str(i_episode+1) + "/" + str(episode_count))
    # The outer loop iterates through each episode, and within each episode:
    state = getState(data, 0, window_size + 1)
      # Initialize state using getState defined above.
    total_profit = 0
      # Initialize total profit: track the financial outcome of the trading strategy throughout the episode.
    agent.inventory = []
      # Initialize inventory: track prices of stocks the agent has bought and not yet sold, representing the agent's current holdings.
    total_buy_actions = 0
    total_sell_actions = 0

    for t in range(l):
        action = agent.act(state)
          # Action Selection: agent decides whether to buy, sell, or hold based on the current state.
          # Decision made using the agent.act(state) method, which implements an ε-greedy policy for exploration and exploitation.

        # Handling Actions:
          # Sit/Hold
        next_state = getState(data, t + 1, window_size + 1)
            # Compute the next_state using historical price data up to time t + 1 within a window size, allowing the agent to observe the outcome of its action.
        reward = 0
            # Initialize reward for the current action as 0.

          # Buy
            # If the agent decides to buy, add shares to its inventory.
        if action == 1:
            agent.inventory.append(data[t])
            total_buy_actions += 1
            print("Buy: " + formatPrice(data[t]))

          # Sell
            # If the agent decides to sell and has shares in its inventory,
            # it sells the oldest share (FIFO - First In, First Out),
            # calculates the profit from the sale, and updates the total profit.
            # The reward is set as the profit from this transaction, ensuring the agent is incentivized to make profitable trades.
        elif action == 2 and len(agent.inventory) > 0: # sell
            bought_price = window_size_price = agent.inventory.pop(0)
            # reward = max(data[t] - bought_price, 0)
            reward = data[t] - bought_price
            total_profit += data[t] - bought_price
            total_sell_actions += 1
            print("Sell: " + formatPrice(data[t]) + " | Profit: " + formatPrice(data[t] - bought_price))

        # Update Agent's Memory:
          # Check if the current timestep is the last one in the episode, setting done to True if so.
        done = True if t == l - 1 else False
          # Store experience (current state, action taken, reward received, next_state, and whether the
          # episode is done) in the agent's memory for future learning.
        agent.memory.append((state, action, reward, next_state, done))
          # Update the current state to the next state for the next timestep.
        state = next_state

        # Print the total profit if one episode is finished.
        if done:
            # Append episode information
            episode_info_list.append({
                    'Episode': i_episode,
                    'Total_Buy_Actions': total_buy_actions,
                    'Total_Sell_Actions': total_sell_actions,
                    'Total_profit': total_profit
                })

            print("--------------------------------")
            print("Total Profit: " + formatPrice(total_profit))
            print("--------------------------------")
      
        # Learning From Experience:
          # Once the agent has accumulated enough experiences in its memory (more than batch_size),
          # it samples a mini-batch of experiences to learn from, adjusting its policy based on the outcomes of past actions.
        if len(agent.memory) > batch_size:
            agent.expReplay(batch_size) # mini-batch size instead of batch size
    scores.append(total_profit)
    # Periodically (every 2 episodes here), the agent's model is saved for later use or evaluation.
    # Useful for tracking progress over time or resuming training later.
    if i_episode % 2 == 0:
        agent.model.save(str(i_episode))

    # Display the episode information DataFrame
episode_df = pd.DataFrame(episode_info_list)
print(episode_df)
# Out:
# Episode 1/20
# Buy: $ 19.26
# Sell: $ 18.36 | Profit: -$ 0.90
# Buy: $ 17.83
# Sell: $ 18.24 | Profit: $ 0.41
# Buy: $ 18.27
# Sell: $ 17.85 | Profit: -$ 0.42
# Buy: $ 17.85
# Sell: $ 18.33 | Profit: $ 0.48
# Buy: $ 18.21
# Buy: $ 18.40
# Buy: $ 17.76
# Buy: $ 18.08
# Sell: $ 18.22 | Profit: $ 0.00
# Sell: $ 17.52 | Profit: -$ 0.89
# Sell: $ 17.24 | Profit: -$ 0.51
# Buy: $ 16.51
# Buy: $ 15.68
# Sell: $ 16.10 | Profit: -$ 1.98
# Buy: $ 15.91
# Sell: $ 16.27 | Profit: -$ 0.24
# Sell: $ 17.00 | Profit: $ 1.33
# Buy: $ 17.02
# Sell: $ 16.47 | Profit: $ 0.56
# Buy: $ 16.32
# Sell: $ 16.13 | Profit: -$ 0.89
# Sell: $ 15.13 | Profit: -$ 1.19
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 12.58
# Sell: $ 12.66 | Profit: $ 0.08
# Buy: $ 12.55
# Sell: $ 12.34 | Profit: -$ 0.20
# Buy: $ 13.73
# Buy: $ 14.19
# Sell: $ 14.33 | Profit: $ 0.60
# Buy: $ 15.00
# Buy: $ 14.98
# Buy: $ 15.10
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 14.79 | Profit: $ 0.60
# Buy: $ 14.65
# Sell: $ 14.62 | Profit: -$ 0.38
# Sell: $ 14.86 | Profit: -$ 0.13
# 1/1 [==============================] - 0s 10ms/step
# Sell: $ 15.14 | Profit: $ 0.05
# Sell: $ 14.97 | Profit: $ 0.32
# Buy: $ 15.36
# Sell: $ 15.34 | Profit: -$ 0.02
# Buy: $ 16.90
# Sell: $ 16.83 | Profit: -$ 0.07
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# Buy: $ 15.72
# Buy: $ 15.59
# 1/1 [==============================] - 0s 10ms/step
# Buy: $ 15.22
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# Buy: $ 15.12
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 15.06
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 14.33 | Profit: -$ 1.38
# Buy: $ 14.37
# Sell: $ 14.78 | Profit: -$ 0.81
# Buy: $ 15.04
# Sell: $ 15.00 | Profit: -$ 0.22
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 15.70
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 16.35 | Profit: $ 1.22
# Sell: $ 16.32 | Profit: $ 1.26
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 16.04
# Sell: $ 16.08 | Profit: $ 1.71
# Sell: $ 14.88 | Profit: -$ 0.16
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 16.06 | Profit: $ 0.36
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 16.31
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 15.54
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 15.85
# Sell: $ 16.00 | Profit: -$ 0.04
# Sell: $ 16.30 | Profit: -$ 0.01
# Sell: $ 16.32 | Profit: $ 0.78
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 17.13
# Sell: $ 17.19 | Profit: $ 1.34
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 17.13 | Profit: -$ 0.00
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 21.00
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 20.99
# Sell: $ 20.89 | Profit: -$ 0.11
# Buy: $ 21.16
# Buy: $ 21.15
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 22.37
# Sell: $ 22.48 | Profit: $ 1.48
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 23.07
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# Buy: $ 23.48
# Sell: $ 23.33 | Profit: $ 2.17
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 23.48
# Sell: $ 23.66 | Profit: $ 2.51
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 22.20
# 1/1 [==============================] - 0s 10ms/step
# Buy: $ 22.42
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 21.93
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 22.00
# Sell: $ 22.32 | Profit: -$ 0.04
# Sell: $ 22.41 | Profit: -$ 0.66
# Buy: $ 22.20
# Sell: $ 22.02 | Profit: -$ 1.45
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 22.39
# Buy: $ 23.26
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 23.89
# Sell: $ 25.43 | Profit: $ 1.95
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# Buy: $ 27.04
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 27.95 | Profit: $ 5.75
# Buy: $ 28.35
# Sell: $ 28.73 | Profit: $ 6.31
# 1/1 [==============================] - 0s 10ms/step
# Buy: $ 28.69
# Sell: $ 27.65 | Profit: $ 5.72
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 27.89
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 28.68
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 29.53
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# Buy: $ 32.81
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 34.99
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 35.86
# Buy: $ 34.57
# Sell: $ 34.03 | Profit: $ 12.04
# Sell: $ 36.48 | Profit: $ 14.28
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 37.97
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 38.15 | Profit: $ 15.75
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 37.65 | Profit: $ 14.40
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 37.20
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 37.79
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 38.73
# Buy: $ 42.72
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 43.37 | Profit: $ 19.48
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 52.00 | Profit: $ 24.96
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 59.14
# Buy: $ 48.98
# 1/1 [==============================] - 0s 8ms/step
# Sell: $ 49.93 | Profit: $ 21.58
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 49.87
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 51.42 | Profit: $ 22.73
# 1/1 [==============================] - 0s 8ms/step
# Sell: $ 51.15 | Profit: $ 23.26
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 53.60 | Profit: $ 24.92
# 1/1 [==============================] - 0s 10ms/step
# Buy: $ 53.34
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 57.23 | Profit: $ 27.69
# Buy: $ 61.16
# Sell: $ 59.96 | Profit: $ 27.15
# Buy: $ 60.07
# Buy: $ 55.59
# Buy: $ 53.33
# 1/1 [==============================] - 0s 10ms/step
# Sell: $ 49.57 | Profit: $ 14.58
# 1/1 [==============================] - 0s 10ms/step
# Sell: $ 49.70 | Profit: $ 13.84
# Sell: $ 49.97 | Profit: $ 15.40
# Buy: $ 48.30
# 1/1 [==============================] - 0s 8ms/step
# Sell: $ 46.90 | Profit: $ 8.93
# Sell: $ 40.53 | Profit: $ 3.33
# 1/1 [==============================] - 0s 10ms/step
# Sell: $ 43.02 | Profit: $ 5.23
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 42.28 | Profit: $ 3.55
# Sell: $ 37.37 | Profit: -$ 5.35
# Buy: $ 36.44
# Buy: $ 29.67
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 28.68 | Profit: -$ 30.46
# 1/1 [==============================] - 0s 10ms/step
# Sell: $ 24.08 | Profit: -$ 24.90
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 28.51 | Profit: -$ 21.36
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 28.50 | Profit: -$ 24.83
# Buy: $ 28.95
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 33.67 | Profit: -$ 27.49
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 35.95 | Profit: -$ 24.12
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 35.21 | Profit: -$ 20.38
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 34.29 | Profit: -$ 19.04
# Buy: $ 34.93
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 32.10 | Profit: -$ 16.20
# 1/1 [==============================] - 0s 10ms/step
# Sell: $ 30.30 | Profit: -$ 6.14
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 32.00 | Profit: $ 2.33
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 34.42 | Profit: $ 5.46
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 36.36 | Profit: $ 1.43
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 26ms/step
# Buy: $ 43.40
# Sell: $ 47.33 | Profit: $ 3.93
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 45.78
# Buy: $ 48.81
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 47.04 | Profit: $ 1.26
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 48.34 | Profit: -$ 0.46
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 51.27
# Buy: $ 53.37
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 52.13 | Profit: $ 0.85
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 46.75 | Profit: -$ 6.61
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 55.67
# 1/1 [==============================] - 0s 23ms/step
# Sell: $ 58.77 | Profit: $ 3.10
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 62.71
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 68.34 | Profit: $ 5.63
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 66.06
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 65.48 | Profit: -$ 0.58
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 101.12
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 103.07 | Profit: $ 1.95
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 125.81
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 125.24 | Profit: -$ 0.57
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# Buy: $ 139.44
# 1/1 [==============================] - 0s 10ms/step
# Sell: $ 110.07 | Profit: -$ 29.37
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 143.00
# Buy: $ 149.39
# 1/1 [==============================] - 0s 12ms/step
# Sell: $ 138.36 | Profit: -$ 4.64
# 1/1 [==============================] - 0s 11ms/step
# Sell: $ 137.99 | Profit: -$ 11.39
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 144.67
# 1/1 [==============================] - 0s 10ms/step
# Sell: $ 147.43 | Profit: $ 2.77
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# Buy: $ 149.63
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 146.56 | Profit: -$ 3.07
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 140.65
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 140.88 | Profit: $ 0.23
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 163.20
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 173.95 | Profit: $ 10.75
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 194.92
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 189.61 | Profit: -$ 5.31
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 246.28
# Buy: $ 246.59
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 238.21 | Profit: -$ 8.07
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 239.66 | Profit: -$ 6.93
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 226.30
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 214.88 | Profit: -$ 11.42
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# Buy: $ 218.43
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 214.46 | Profit: -$ 3.97
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 235.43
# 1/1 [==============================] - 0s 11ms/step
# Sell: $ 236.16 | Profit: $ 0.73
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 264.54
# 1/1 [==============================] - 0s 10ms/step
# Sell: $ 261.83 | Profit: -$ 2.71
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 344.47
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 351.58 | Profit: $ 7.10
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 362.71
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 342.32 | Profit: -$ 20.39
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 310.00
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 312.47 | Profit: $ 2.47
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# Buy: $ 302.45
# 1/1 [==============================] - 0s 10ms/step
# Sell: $ 307.33 | Profit: $ 4.89
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 254.68
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 290.14 | Profit: $ 35.46
# Buy: $ 288.12
# 1/1 [==============================] - 0s 10ms/step
# Sell: $ 293.30 | Profit: $ 5.17
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 363.75
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 352.42 | Profit: -$ 11.33
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 325.31
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# Sell: $ 340.79 | Profit: $ 15.48
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 328.33
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 334.76 | Profit: $ 6.43
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 332.67
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 293.84 | Profit: -$ 38.84
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 290.25
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 303.08 | Profit: $ 12.83
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 262.37
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 266.68 | Profit: $ 4.31
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 215.74
# 1/1 [==============================] - 0s 10ms/step
# Sell: $ 220.89 | Profit: $ 5.15
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 232.66
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# Buy: $ 224.47
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# Sell: $ 231.73 | Profit: -$ 0.93
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 244.54 | Profit: $ 20.07
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 258.86
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 274.82 | Profit: $ 15.96
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 296.67
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 289.91
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 277.70
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 275.61
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 274.42 | Profit: -$ 22.25
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 289.26 | Profit: -$ 0.65
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 299.68 | Profit: $ 21.98
# 1/1 [==============================] - 0s 11ms/step
# Sell: $ 304.42 | Profit: $ 28.81
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 300.80
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 275.33
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 276.01
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 287.81 | Profit: -$ 12.99
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 268.21 | Profit: -$ 7.12
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 265.25 | Profit: -$ 10.76
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 240.81
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 238.13
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 216.50
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 204.99 | Profit: -$ 35.82
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 219.35 | Profit: -$ 18.78
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 222.04 | Profit: $ 5.54
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 207.47
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 197.08
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 191.30
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 177.59
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 190.95 | Profit: -$ 16.52
# 1/1 [==============================] - 0s 11ms/step
# Sell: $ 194.42 | Profit: -$ 2.66
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 183.17
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 180.19
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 167.87
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 169.91
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 182.86 | Profit: -$ 8.44
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 182.92 | Profit: $ 5.33
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 180.83 | Profit: -$ 2.34
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 194.70 | Profit: $ 14.51
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 194.70
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 194.86 | Profit: $ 26.99
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 179.82 | Profit: $ 9.91
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 174.04
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 173.44
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 157.67
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 150.23
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 125.35
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 123.15
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 109.10
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# Sell: $ 123.18 | Profit: -$ 71.52
# 1/1 [==============================] - 0s 10ms/step
# Sell: $ 108.10 | Profit: -$ 65.94
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 113.64 | Profit: -$ 59.80
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 110.34
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 113.06
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 118.85 | Profit: -$ 38.82
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 123.22 | Profit: -$ 27.01
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 123.56 | Profit: -$ 1.79
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 122.40
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 128.78 | Profit: $ 5.63
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 127.17
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 143.75 | Profit: $ 34.65
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 144.43 | Profit: $ 34.09
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 160.27 | Profit: $ 47.21
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 177.90 | Profit: $ 55.50
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 173.22 | Profit: $ 46.05
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 194.64
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 209.25 | Profit: $ 14.61
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 202.04
# 1/1 [==============================] - 0s 9ms/step
# Sell: $ 208.31 | Profit: $ 6.27
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# --------------------------------
# Total Profit: $ 80.10
# --------------------------------
# INFO:tensorflow:Assets written to: 0/assets
# INFO:tensorflow:Assets written to: 0/assets
# Episode 2/20
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# ...
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# Buy: $ 307.48
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# Sell: $ 270.21 | Profit: -$ 37.27
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# Buy: $ 220.19
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# --------------------------------
# Total Profit: $ 99.24
# --------------------------------
# INFO:tensorflow:Assets written to: 20/assets
# INFO:tensorflow:Assets written to: 20/assets
#     Episode  Total_Buy_Actions  Total_Sell_Actions  Total_profit
# 0         0                152                 152     80.098168
# 1         1                129                 129    120.102821
# 2         2                 34                  34    175.390594
# 3         3                 65                  65    263.353958
# 4         4                203                 201   2365.323244
# 5         5                 56                  55     64.217361
# 6         6                 56                  56   7109.301297
# 7         7                 63                  24  -1219.622036
# 8         8                  4                   1    126.840012
# 9         9                163                   5    744.246001
# 10       10                136                 136   8006.291939
# 11       11                132                 132  11877.446053
# 12       12                 47                   2   -120.293327
# 13       13                265                 265  44398.819388
# 14       14                164                 130  -7272.503273
# 15       15                 38                   2      1.782000
# 16       16                  9                   1    221.647338
# 17       17                 22                   1    100.288002
# 18       18                 13                   3    237.442680
# 19       19                 21                  21   -206.467329
# 20       20                  3                   2     99.240005

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.savefig('training_scores.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# Run a stock trading simulation using a pre-trained Deep Q-Network (DQN) model.

# Model Loading:
  # Takes a user input for the model name.
  # Loads a pre-trained model based on the provided name.
model_name = input()
model = load_model(model_name)

# Extracts the window size from the input shape of the first layer of the model,
# which indicates how many past time steps (e.g., days of stock prices) the model expects as input.
window_size = model.layers[0].input.shape.as_list()[1]

# Initialize an agent for evaluation (True parameter indicates evaluation mode),
# with the window size derived from the model and the name of the model.
agent = Agent(window_size, True, model_name)

# Initialize data, batch_size, initial state, initial profit, and inventory (similar as training part).
data=list(price_df['Close'][1000:])
data_df = pd.DataFrame(data, columns=['Close'])

l = len(data) - 1
batch_size = 32
state = getState(data, 0, window_size + 1)
total_profit = 0
action_list = []
agent.inventory = []

# Similar work as in the training process, except that there is no model training step:
for t in range(l):
    action = agent.act(state)
    print(action)
    # sit
    next_state = getState(data, t + 1, window_size + 1)
    reward = 0
    if action == 1: # buy
        agent.inventory.append(data[t])
        action_list.append(action)
        print("Buy: " + formatPrice(data[t]))

    elif action == 2 and len(agent.inventory) > 0: # sell
        bought_price = agent.inventory.pop(0)
        reward = max(data[t] - bought_price, 0)
        total_profit += data[t] - bought_price
        action_list.append(action)
        print("Sell: " + formatPrice(data[t]) + " | Profit: " + formatPrice(data[t] - bought_price))

    else:
        action_list.append(0)
    
    done = True if t == l - 1 else False
    agent.memory.append((state, action, reward, next_state, done))
    state = next_state

    if done:
        print("--------------------------------")
        print(ticker + " Total Profit: " + formatPrice(total_profit))
        action_list.append(0)
        data_df['action'] = action_list
        data_df["Close"].plot(figsize=(8, 5), grid=True)
        sell_signals = data_df[data_df['action'] == 2]
        buy_signals = data_df[data_df['action'] == 1]

        plt.scatter(sell_signals.index, sell_signals["Close"], c='r', marker='v', label='Sell')
        plt.scatter(buy_signals.index, buy_signals["Close"], c='g', marker='^', label='Buy')

        plt.legend(['value', 'sell', 'buy'])
        plt.title('total profit %f'%(total_profit))
        plt.savefig('evaluating_graph.png')
        plt.show()

    # Notice that there are several main differences between evaluation process and training process before:
    # 1. Exploitation Only: The agent exclusively uses its learned policy to make decisions, without random exploration.
    # 2. No Model Updates: The agent does not update its model during evaluation. Experiences may still be stored (for review or analysis),
    # but they are not used for training. The focus is on assessing the effectiveness of the current policy.
    # 3. Consistent Policy: Since the model is not being updated, the agent's policy remains consistent throughout the evaluation phase.
# Out:
# 1/1 [==============================] - 0s 42ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 1
# Buy: $ 190.90
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 16ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 19ms/step
# 0
# 1/1 [==============================] - 0s 17ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 183.26
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 184.13 | Profit: -$ 6.77
# 1/1 [==============================] - 0s 16ms/step
# 1
# Buy: $ 180.13
# 1/1 [==============================] - 0s 16ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 197.58 | Profit: $ 14.32
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 191.15 | Profit: $ 11.02
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 1
# Buy: $ 190.41
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 16ms/step
# 0
# 1/1 [==============================] - 0s 16ms/step
# 0
# 1/1 [==============================] - 0s 16ms/step
# 1
# Buy: $ 195.28
# 1/1 [==============================] - 0s 16ms/step
# 2
# Sell: $ 207.46 | Profit: $ 17.05
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 194.77 | Profit: -$ 0.51
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 13ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 16ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 1
# Buy: $ 187.04
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 160.31
# 1/1 [==============================] - 0s 18ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 170.06 | Profit: -$ 16.98
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 171.79 | Profit: $ 11.48
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 1
# Buy: $ 172.08
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 17ms/step
# 0
# 1/1 [==============================] - 0s 16ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 176.89 | Profit: $ 4.81
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 20ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 193.17
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 201.16 | Profit: $ 7.99
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 260.54
# 1/1 [==============================] - 0s 17ms/step
# 1
# Buy: $ 274.45
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 264.61 | Profit: $ 4.07
# 1/1 [==============================] - 0s 14ms/step
# 1
# Buy: $ 256.60
# 1/1 [==============================] - 0s 13ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 1
# Buy: $ 256.24
# 1/1 [==============================] - 0s 19ms/step
# 2
# Sell: $ 257.50 | Profit: -$ 16.95
# 1/1 [==============================] - 0s 88ms/step
# 2
# Sell: $ 261.77 | Profit: $ 5.17
# 1/1 [==============================] - 0s 26ms/step
# 2
# Sell: $ 279.82 | Profit: $ 23.58
# 1/1 [==============================] - 0s 21ms/step
# 2
# 1/1 [==============================] - 0s 16ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 274.43
# 1/1 [==============================] - 0s 16ms/step
# 0
# 1/1 [==============================] - 0s 16ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 1
# Buy: $ 277.90
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 281.38 | Profit: $ 6.95
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 290.38 | Profit: $ 12.48
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 1
# Buy: $ 262.90
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 16ms/step
# 0
# 1/1 [==============================] - 0s 16ms/step
# 0
# 1/1 [==============================] - 0s 22ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 236.86 | Profit: -$ 26.04
# 1/1 [==============================] - 0s 24ms/step
# 0
# 1/1 [==============================] - 0s 17ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 17ms/step
# 1
# Buy: $ 276.04
# 1/1 [==============================] - 0s 19ms/step
# 2
# Sell: $ 274.39 | Profit: -$ 1.65
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 265.28
# 1/1 [==============================] - 0s 20ms/step
# 0
# 1/1 [==============================] - 0s 19ms/step
# 0
# 1/1 [==============================] - 0s 16ms/step
# 0
# 1/1 [==============================] - 0s 24ms/step
# 0
# 1/1 [==============================] - 0s 17ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 19ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 19ms/step
# 1
# Buy: $ 250.22
# 1/1 [==============================] - 0s 18ms/step
# 2
# Sell: $ 251.60 | Profit: -$ 13.68
# 1/1 [==============================] - 0s 16ms/step
# 2
# Sell: $ 246.53 | Profit: -$ 3.69
# 1/1 [==============================] - 0s 16ms/step
# 1
# Buy: $ 261.16
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 260.05 | Profit: -$ 1.11
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 16ms/step
# 1
# Buy: $ 259.67
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 263.62
# 1/1 [==============================] - 0s 14ms/step
# 1
# Buy: $ 262.99
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 17ms/step
# 0
# 1/1 [==============================] - 0s 16ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 13ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 218.51 | Profit: -$ 41.16
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 219.96 | Profit: -$ 43.66
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 219.27 | Profit: -$ 43.72
# 1/1 [==============================] - 0s 16ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 209.98
# 1/1 [==============================] - 0s 14ms/step
# 1
# Buy: $ 214.65
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 223.71
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 237.41 | Profit: $ 27.43
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 242.84 | Profit: $ 28.19
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 233.59 | Profit: $ 9.88
# 1/1 [==============================] - 0s 15ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 235.45
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 236.08 | Profit: $ 0.63
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 20ms/step
# 1
# Buy: $ 244.14
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 242.64 | Profit: -$ 1.50
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 16ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 16ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 1
# Buy: $ 251.05
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 253.50 | Profit: $ 2.45
# 1/1 [==============================] - 0s 15ms/step
# 2
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 17ms/step
# 0
# 1/1 [==============================] - 0s 32ms/step
# 0
# 1/1 [==============================] - 0s 20ms/step
# 0
# 1/1 [==============================] - 0s 18ms/step
# 0
# 1/1 [==============================] - 0s 19ms/step
# 0
# 1/1 [==============================] - 0s 18ms/step
# 0
# 1/1 [==============================] - 0s 17ms/step
# 0
# 1/1 [==============================] - 0s 16ms/step
# 0
# 1/1 [==============================] - 0s 17ms/step
# 0
# 1/1 [==============================] - 0s 17ms/step
# 0
# 1/1 [==============================] - 0s 17ms/step
# 0
# 1/1 [==============================] - 0s 17ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 191.59
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 187.29
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 188.86
# 1/1 [==============================] - 0s 17ms/step
# 1
# Buy: $ 187.91
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 185.10
# 1/1 [==============================] - 0s 17ms/step
# 1
# Buy: $ 187.58
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 189.56 | Profit: -$ 2.03
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 193.57 | Profit: $ 6.28
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 188.13 | Profit: -$ 0.73
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 200.45
# 1/1 [==============================] - 0s 14ms/step
# 1
# Buy: $ 199.95
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 193.76 | Profit: $ 5.85
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 1
# Buy: $ 197.41
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 199.40 | Profit: $ 14.30
# 1/1 [==============================] - 0s 14ms/step
# 1
# Buy: $ 199.73
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 202.04 | Profit: $ 14.46
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 201.88 | Profit: $ 1.43
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 202.64 | Profit: $ 2.69
# 1/1 [==============================] - 0s 16ms/step
# 2
# Sell: $ 188.14 | Profit: -$ 9.27
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 15ms/step
# 0
# --------------------------------
# TSLA Total Profit: $ 3.06
