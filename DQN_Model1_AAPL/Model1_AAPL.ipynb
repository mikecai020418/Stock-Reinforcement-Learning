# %% [markdown]
# ## Reinforcement Learning

# %% [markdown]
# We first write a function to create a data frame including stock price data for the past 5 years including open, close, low, and high prices. We also add columns for the difference between open and close prices, the difference between high and low prices, and whether that month is the end of a quarter to predict the buy or not for investors.

# %%
import keras
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense
from tensorflow.keras.optimizers.legacy import Adam
import tensorflow as tf

import yfinance as yf
import math
import numpy as np
import pandas as pd
import random
from collections import deque

# %%
def create_price_df(ticker):
    """
    ticker: the chosen company stock

    Return: returns a dataframe of a company's stock price data and features we want to use in machine learning model
    """
    price_df = price_df=yf.download(tickers = ticker, period = "5y", interval = "1d",
    prepost = False, repair = True)
    price_df["date"]=price_df.index
    price_df.reset_index()
    price_df["Date"] = price_df["date"].transform(lambda x: x.date())
    price_df["Date"] = price_df["Date"].transform(lambda x: str(x))
    price_df = price_df.drop(['date'],axis=1)
    splitted=price_df['Date'].str.split('-',expand = True)
    price_df['day'] = splitted[2].astype('int')
    price_df['month'] = splitted[1].astype('int')
    price_df['year'] = splitted[0].astype('int')
    price_df['is_quarter_end']=np.where(price_df['month']%3 == 0,1,0)
    price_df['open-close']  = price_df['Open'] - price_df['Close']
    price_df['low-high']  = price_df['Low'] - price_df['High']
    price_df['target'] = np.where(price_df['Close'].shift(-1) > price_df['Close'], 1, 0)
    #if the close price of the previous day is higher than today's close price, then the investor will buy the stock
    return price_df

# %%
# ticker is basically a abbreviation for a company stock.
ticker=input("Please enter your ticker: ")
price_df = create_price_df(ticker = ticker)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
price_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-03-12   45.000000   45.667500   44.842499   45.227501   43.540466
# 2019-03-13   45.562500   45.825001   45.230000   45.427502   43.733009
# 2019-03-14   45.974998   46.025002   45.639999   45.932499   44.219173
# 2019-03-15   46.212502   46.832500   45.935001   46.529999   44.794380
# 2019-03-18   46.450001   47.097500   46.447498   47.005001   45.251656
# ...                ...         ...         ...         ...         ...
# 2024-03-06  171.059998  171.240005  168.679993  169.119995  169.119995
# 2024-03-07  169.149994  170.729996  168.490005  169.000000  169.000000
# 2024-03-08  169.000000  173.699997  168.940002  170.729996  170.729996
# 2024-03-11  172.940002  174.380005  172.050003  172.750000  172.750000
# 2024-03-12  173.149994  173.470001  171.020004  172.259995  172.259995
#
#                Volume  Repaired?        Date  day  month  year  \
# Date
# 2019-03-12  129870400      False  2019-03-12   12      3  2019
# 2019-03-13  124130000      False  2019-03-13   13      3  2019
# 2019-03-14   94318000      False  2019-03-14   14      3  2019
# 2019-03-15  156171600      False  2019-03-15   15      3  2019
# 2019-03-18  104879200      False  2019-03-18   18      3  2019
# ...               ...        ...         ...  ...    ...   ...
# 2024-03-06   68587700      False  2024-03-06    6      3  2024
# 2024-03-07   71765100      False  2024-03-07    7      3  2024
# 2024-03-08   76114600      False  2024-03-08    8      3  2024
# 2024-03-11   60068800      False  2024-03-11   11      3  2024
# 2024-03-12   28980318      False  2024-03-12   12      3  2024
#
#             is_quarter_end  open-close  low-high  target
# Date
# 2019-03-12               1   -0.227501 -0.825001       1
# 2019-03-13               1    0.134998 -0.595001       1
# 2019-03-14               1    0.042500 -0.385002       1
# 2019-03-15               1   -0.317497 -0.897499       1
# 2019-03-18               1   -0.555000 -0.650002       0
# ...                    ...         ...       ...     ...
# 2024-03-06               1    1.940002 -2.560013       0
# 2024-03-07               1    0.149994 -2.239990       1
# 2024-03-08               1   -1.729996 -4.759995       1
# 2024-03-11               1    0.190002 -2.330002       0
# 2024-03-12               1    0.889999 -2.449997       0
#
# [1260 rows x 15 columns]

# %% [markdown]
# The code sets up a reinforcement learning agent with a neural network model that learns to make decisions (buying, selling, or sitting) in a stock trading environment. The agent learns from its experiences using the Q-learning algorithm and improves its performance over time through repeated interactions with the environment.

# %% [markdown]
# The act method determines the agent's action based on the current state. The neural network model predicts the Q-values for the current state. These predicted Q-values correspond to the estimated future rewards for each possible action the agent can take. The agent then chooses the action with the highest predicted Q-value, unless it is in evaluation mode (is_eval=True) or randomly selected due to exploration.

# %% [markdown]
# The expReplay method implements experience replay. It samples a batch of experiences from the memory and updates the model's weights based on the Bellman equation, which estimates the optimal action-value function (Q-value).

# %%
# Agent class
class Agent:
    def __init__(self, state_size, is_eval=False, model_name=""):
        """Initialize Agent class:
        Define static variables like gamma, epsilon, epsilon_min, and epsilon_decay to
          manage the trade-off between exploration and exploitation in the decision-making process.
        Gamma (discount factor) influences how future rewards are valued.
        Epsilon controls the rate of exploration versus exploitation,
          with epsilon_min and epsilon_decay dictating the minimum exploration rate and how quickly exploration decreases, respectively.
        These parameters are crucial for the agent's strategy in buying and selling stocks,
          ensuring a balance between exploiting known strategies and exploring new possibilities."""

        self.state_size = state_size
          # length of the historical sequence of stock prices that the agent uses as its input state size, measured in trading days
        self.action_size = 3
          # 3 actions: sit, buy, sell
        self.memory = deque(maxlen=1000)
          # internal memory with maximum length 1000, used for experience replay;
          # allows the agent to learn from past experiences.
        self.inventory = []
          # keep track of the stocks currently held by the agent
          # A "buy" action adds the stock to the inventory, while a "sell" action removes it.
        self.model_name = model_name
          # name of the model
        self.is_eval = is_eval
          # evaluation flag
        self.gamma = 0.95
          # discount rate for the next state; determines the present value of future rewards;
          # As γ is closer to 0, the agent prioritizes immediate rewards more heavily, focusing on short-term gains;
          # As γ approaches 1, the agent places greater value on future rewards, encouraging strategies with more
          # pay-off in the long run.
        self.epsilon = 1.0
          # exploration rate; used to implement the ϵ-greedy strategy, where the agent randomly explores the
          # environment with a probability of ϵ and exploits its current knowledge with a probability of 1−ϵ;
          # If epsilon is set to 0, we never explore but always exploit the knowledge we already have.
          # On the contrary, a higher value of ϵ (closer to 1) is used to encourage exploration of the environment.
        self.epsilon_min = 0.01
          # minimum exploration probability; sets the lower bound of ϵ;
          # ensure the agent continues to explore the environment to a certain extent even after extensive training.
        self.epsilon_decay = 0.995
          # exponential decay rate for exploration prob; controls the rate at which ϵ decreases over time;
          # gradually shifting the agent's strategy from exploration towards exploitation.
        self.model = load_model(model_name) if is_eval else self._model()
          # load model if is_eval is true, else create a new model

    def _model(self):
        """Neural Network Model"""
        # # create a neural network model with 3 hidden layers, to predict the reward value of actions.
        # model = Sequential()
        # model.add(Dense(units=64, input_dim=self.state_size, activation="relu"))
        # model.add(Dense(units=32, activation="relu"))
        # model.add(Dense(units=8, activation="relu"))
        # model.add(Dense(self.action_size, activation="linear"))
        # model.compile(loss="mse", optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])
        # # mean squared error loss, adam optimizer with learning rate of 0.001
        
        model = tf.keras.Sequential([
            # Input layer: No need to explicitly set an input layer. The input shape will be determined in the first Dense layer.
            # First Dense layer with ReLU activation. The `input_dim` parameter specifies the size of the input layer.
            tf.keras.layers.Dense(units=16, activation='relu', input_dim=self.state_size),

            # Second Dense layer with ReLU activation.
            tf.keras.layers.Dense(units=8, activation='relu'),

            # Output layer with linear activation, since we're predicting Q-values which are continuous.
            tf.keras.layers.Dense(units=self.action_size, activation='linear')
        ])

        # Compile the model. For a Q-learning model, we typically use the Mean Squared Error (MSE) loss and an optimizer like Adam.
        model.compile(optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001),
                      loss='mse',
                      metrics=['accuracy'])  # Metrics are optional and may not be very meaningful in this context.
        return model

    def act(self, state):
        """Agent will act upon the current state:
        defines how the agent chooses an action based on the current state it is in."""
        # Exploration:
        if not self.is_eval and random.random()<= self.epsilon:
            # Check if the agent is not in evaluation mode and
            # if a randomly generated number between 0 and 1 is within the boundary.
            # If both conditions are met, the agent is in the exploration phase,
            # and an action is chosen randomly from the available action space.
            return random.randrange(self.action_size)
        # Exploitation:
            # If the agent decides not to explore, it enters the exploitation phase;
            # it chooses the action that it believes will yield the highest reward based on current knowledge.
        options = self.model.predict(state)
            # given the current state, use the agent's NN model to predict the reward value of each possible action.
        return np.argmax(options[0])
            # select the action with the highest predicted reward.

    def expReplay(self, batch_size):
        """Experience Replay
        Involves storing past experiences (state, action, reward, next_state, done) in a memory
        buffer and later randomly sampling a mini-batch of these experiences to train the model."""

        minibatch = random.sample(self.memory, batch_size)
        states = np.array([i[0] for i in minibatch])
        actions = np.array([i[1] for i in minibatch])
        rewards = np.array([i[2] for i in minibatch])
        next_states = np.array([i[3] for i in minibatch])
        dones = np.array([i[4] for i in minibatch])

        states = np.squeeze(states)
        next_states = np.squeeze(next_states)

        targets = rewards + self.gamma*(np.amax(self.model.predict_on_batch(next_states), axis=1))*(1-dones)
        targets_full = self.model.predict_on_batch(states)

        ind = np.array([i for i in range(batch_size)])
        targets_full[[ind], [actions]] = targets

        self.model.fit(states, targets_full, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
def formatPrice(n):
    """Format price"""
    # format price as $x.xx
    return("-$ " if n<0 else "$ ")+"{0:.2f}".format(abs(n))

def sigmoid(x):
    """Sigmoid function"""
    # sigmoid "squashing" function to interval [0,1], for normalization purpose
    return 1/(1+math.exp(-x))

def getState(data, t, n):
    """Get state
    data: A list or array containing the historical data points (e.g., stock prices).
    t: The current timestep for which the state is being generated.
    n: The window size, indicating how many timesteps back the state should consider."""
    d = t - n + 1
      # Calculate the starting index of the data block that will be used to generate the state.
      # d identifies the earliest timestep in the window.

    block = data[d:t + 1] if d >= 0 else -d * [data[0]] + data[0:t + 1]
      # Extract the relevant block of data for the state.
      # If d is non-negative, it directly slices the data array from d to t, inclusive.
      # Else(the window extends beyond the start of the available data), it pads the
      # beginning of the block with the value at data[0]. The number of times data[0] is
      # repeated corresponds to -d, ensuring the resulting block has a length of n.

    res = []
      # list to store the price changes within the window.
    for i in range(n - 1):
        res.append(sigmoid(block[i + 1] - block[i]))
        # calculate price change between successive timesteps and apply the sigmoid function to each change.

    # return array of price changes
    return np.array([res])

# %% [markdown]
# The code below performs the training loop for the reinforcement learning agent in the stock trading environment. It interacts with the environment, executes actions, and updates the agent's neural network model based on the observed rewards.

# %% [markdown]
# One thing to note is the agent's memory. The agent's memory is used for experience replay, which is a technique in reinforcement learning that helps improve the agent's learning efficiency and stability. During the training process, the agent samples a batch of experiences from its memory and uses them to update its model through a process called experience replay. This helps the agent learn from a diverse set of experiences and reduces the correlation between consecutive samples.

# %%
import sys
# window_size = input()
# episode_count = input()
window_size = 6
episode_count = 20

window_size = int(window_size)
  # Window size represents the length of historical sequence of stock prices that the agent uses as its input state.
  # This allows the agent to consider patterns over a specified number of previous time steps when making decisions.
  # By setting a larger window size, the agent can capture more historical price patterns and possibly make more informed decisions.
episode_count = int(episode_count)
  # The number of episodes for which the agent will be trained.
  # Each episode represents a complete sequence of decisions (trading actions) from start to finish based on the data.

agent = Agent(window_size)
  # Initialize agent
  # Recall that def __init__(self, state_size, is_eval=False, model_name="")

data=list(price_df['Close'][0:1000])
  # Get the stock data
  # specifically the closing prices, which the agent uses to learn trading strategies.

l = len(data) - 1  # data length
batch_size = 32    # batch size

# Initialize episode information list
episode_info_list = []
scores = []
# Training Loop:
for i_episode in range(episode_count+1):
    print("Episode " + str(i_episode+1) + "/" + str(episode_count))
    # The outer loop iterates through each episode, and within each episode:
    state = getState(data, 0, window_size + 1)
      # Initialize state using getState defined above.
    total_profit = 0
      # Initialize total profit: track the financial outcome of the trading strategy throughout the episode.
    agent.inventory = []
      # Initialize inventory: track prices of stocks the agent has bought and not yet sold, representing the agent's current holdings.
    total_buy_actions = 0
    total_sell_actions = 0

    for t in range(l):
        action = agent.act(state)
          # Action Selection: agent decides whether to buy, sell, or hold based on the current state.
          # Decision made using the agent.act(state) method, which implements an ε-greedy policy for exploration and exploitation.

        # Handling Actions:
          # Sit/Hold
        next_state = getState(data, t + 1, window_size + 1)
            # Compute the next_state using historical price data up to time t + 1 within a window size, allowing the agent to observe the outcome of its action.
        reward = 0
            # Initialize reward for the current action as 0.

          # Buy
            # If the agent decides to buy, add shares to its inventory.
        if action == 1:
            agent.inventory.append(data[t])
            total_buy_actions += 1
            print("Buy: " + formatPrice(data[t]))

          # Sell
            # If the agent decides to sell and has shares in its inventory,
            # it sells the oldest share (FIFO - First In, First Out),
            # calculates the profit from the sale, and updates the total profit.
            # The reward is set as the profit from this transaction, ensuring the agent is incentivized to make profitable trades.
        elif action == 2 and len(agent.inventory) > 0: # sell
            bought_price = window_size_price = agent.inventory.pop(0)
            # reward = max(data[t] - bought_price, 0)
            reward = data[t] - bought_price
            total_profit += data[t] - bought_price
            total_sell_actions += 1
            print("Sell: " + formatPrice(data[t]) + " | Profit: " + formatPrice(data[t] - bought_price))

        # Update Agent's Memory:
          # Check if the current timestep is the last one in the episode, setting done to True if so.
        done = True if t == l - 1 else False
          # Store experience (current state, action taken, reward received, next_state, and whether the
          # episode is done) in the agent's memory for future learning.
        agent.memory.append((state, action, reward, next_state, done))
          # Update the current state to the next state for the next timestep.
        state = next_state

        # Print the total profit if one episode is finished.
        if done:
            # Append episode information
            episode_info_list.append({
                    'Episode': i_episode,
                    'Total_Buy_Actions': total_buy_actions,
                    'Total_Sell_Actions': total_sell_actions,
                    'Total_profit': total_profit
                })

            print("--------------------------------")
            print("Total Profit: " + formatPrice(total_profit))
            print("--------------------------------")
      
        # Learning From Experience:
          # Once the agent has accumulated enough experiences in its memory (more than batch_size),
          # it samples a mini-batch of experiences to learn from, adjusting its policy based on the outcomes of past actions.
        if len(agent.memory) > batch_size:
            agent.expReplay(batch_size) # mini-batch size instead of batch size
    scores.append(total_profit)
    # Periodically (every 2 episodes here), the agent's model is saved for later use or evaluation.
    # Useful for tracking progress over time or resuming training later.
    if i_episode % 2 == 0:
        agent.model.save(str(i_episode))

    # Display the episode information DataFrame
episode_df = pd.DataFrame(episode_info_list)
print(episode_df)
# Out:
# Episode 1/20
# Buy: $ 45.23
# Sell: $ 45.43 | Profit: $ 0.20
# Buy: $ 45.93
# Buy: $ 46.53
# Sell: $ 47.01 | Profit: $ 1.07
# Sell: $ 46.63 | Profit: $ 0.10
# Buy: $ 47.04
# Buy: $ 47.76
# Sell: $ 47.19 | Profit: $ 0.15
# Buy: $ 46.70
# Buy: $ 47.12
# Sell: $ 47.49 | Profit: -$ 0.28
# Buy: $ 47.81
# Buy: $ 48.51
# Buy: $ 48.84
# Buy: $ 49.25
# Sell: $ 49.88 | Profit: $ 3.18
# Buy: $ 50.15
# Sell: $ 49.74 | Profit: $ 2.62
# Buy: $ 49.72
# Sell: $ 49.81 | Profit: $ 2.00
# Sell: $ 50.78 | Profit: $ 2.28
# Sell: $ 50.97 | Profit: $ 2.13
# Buy: $ 51.13
# Buy: $ 51.79
# Sell: $ 51.32 | Profit: $ 2.07
# Sell: $ 51.08 | Profit: $ 0.92
# Sell: $ 50.17 | Profit: $ 0.45
# Buy: $ 52.29
# Sell: $ 52.94 | Profit: $ 1.81
# Buy: $ 52.12
# Sell: $ 50.72 | Profit: -$ 1.07
# Buy: $ 50.18
# Buy: $ 49.29
# Sell: $ 46.43 | Profit: -$ 5.86
# Sell: $ 47.17 | Profit: -$ 4.95
# Sell: $ 47.73 | Profit: -$ 2.45
# Buy: $ 47.52
# Buy: $ 47.25
# Buy: $ 45.77
# Sell: $ 44.92 | Profit: -$ 4.38
# Buy: $ 44.74
# Buy: $ 44.56
# 1/1 [==============================] - 0s 34ms/step
# Buy: $ 44.58
# Buy: $ 43.33
# Buy: $ 45.63
# Sell: $ 46.31 | Profit: -$ 1.22
# Sell: $ 48.15 | Profit: $ 0.90
# Buy: $ 48.70
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 48.19
# Sell: $ 48.47 | Profit: $ 2.70
# Buy: $ 49.61
# Sell: $ 49.47 | Profit: $ 4.72
# Buy: $ 49.87
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 48.89 | Profit: $ 4.34
# Buy: $ 49.95
# Sell: $ 49.94 | Profit: $ 5.36
# Buy: $ 49.48
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 50.68 | Profit: $ 7.36
# Buy: $ 51.10
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 50.44 | Profit: $ 4.80
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 51.42 | Profit: $ 2.71
# Buy: $ 50.65
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 52.17
# Buy: $ 51.76
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 52.42 | Profit: $ 4.23
# Buy: $ 52.19
# Sell: $ 53.26 | Profit: $ 3.65
# Sell: $ 52.11 | Profit: $ 2.24
# Buy: $ 51.01
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 49.76 | Profit: -$ 0.19
# Sell: $ 50.86 | Profit: $ 1.38
# Buy: $ 50.12
# Sell: $ 52.24 | Profit: $ 1.14
# Sell: $ 50.69 | Profit: $ 0.04
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 50.44 | Profit: -$ 1.73
# Sell: $ 52.59 | Profit: $ 0.83
# Buy: $ 52.59
# Sell: $ 53.16 | Profit: $ 0.97
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 53.12 | Profit: $ 2.11
# Buy: $ 50.66
# Buy: $ 51.62
# Buy: $ 51.38
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 52.25 | Profit: $ 2.13
# Buy: $ 52.30
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 53.31 | Profit: $ 0.72
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 53.54 | Profit: $ 2.88
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 54.17 | Profit: $ 2.55
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 55.77 | Profit: $ 4.39
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 54.69 | Profit: $ 2.39
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 55.21
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 56.75 | Profit: $ 1.55
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 56.76
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 57.52 | Profit: $ 0.76
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 60.90
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 61.65 | Profit: $ 0.75
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 66.78
# Buy: $ 66.57
# Buy: $ 65.80
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 65.50 | Profit: -$ 1.27
# Buy: $ 65.44
# Sell: $ 66.59 | Profit: $ 0.02
# Buy: $ 66.07
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 66.96 | Profit: $ 1.16
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 66.81 | Profit: $ 1.37
# Buy: $ 66.04
# Sell: $ 64.86 | Profit: -$ 1.21
# Sell: $ 65.43 | Profit: -$ 0.61
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 66.73
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 67.12 | Profit: $ 0.39
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 69.96
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 70.10 | Profit: $ 0.14
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 69.86
# Sell: $ 71.00 | Profit: $ 1.14
# Buy: $ 71.07
# Buy: $ 72.48
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 72.45 | Profit: $ 1.38
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 72.88 | Profit: $ 0.40
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 75.80
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 79.24 | Profit: $ 3.44
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 79.81
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 79.58 | Profit: -$ 0.23
# Buy: $ 77.24
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 79.42 | Profit: $ 2.18
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 80.01
# Sell: $ 80.39 | Profit: $ 0.38
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 81.24
# Sell: $ 80.90 | Profit: -$ 0.33
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 72.02
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 73.16 | Profit: $ 1.14
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 68.34
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 74.70 | Profit: $ 6.36
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 72.26
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 66.54 | Profit: -$ 5.71
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 71.33
# 1/1 [==============================] - 0s 17ms/step
# Sell: $ 68.86 | Profit: -$ 2.48
# 1/1 [==============================] - 0s 16ms/step
# Buy: $ 62.06
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 60.55 | Profit: -$ 1.50
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 63.22
# Sell: $ 61.67 | Profit: -$ 1.55
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 56.09
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 61.38 | Profit: $ 5.29
# Buy: $ 64.61
# Buy: $ 61.94
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 60.23
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 60.35 | Profit: -$ 4.26
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 65.62 | Profit: $ 3.68
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 64.86 | Profit: $ 4.63
# Buy: $ 66.52
# Sell: $ 67.00 | Profit: $ 0.48
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 69.23
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 69.03 | Profit: -$ 0.21
# Buy: $ 68.76
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 70.74 | Profit: $ 1.99
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 69.64
# Buy: $ 71.93
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 73.45 | Profit: $ 3.81
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 72.27 | Profit: $ 0.33
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 75.93
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 77.53 | Profit: $ 1.60
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 82.88
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 83.36 | Profit: $ 0.49
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 83.97
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 85.75 | Profit: $ 1.77
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 87.93
# Buy: $ 87.43
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 89.72 | Profit: $ 1.78
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 91.63 | Profit: $ 4.20
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 91.21
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 88.41 | Profit: -$ 2.80
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 90.44
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 91.20 | Profit: $ 0.75
# 1/1 [==============================] - 0s 16ms/step
# Buy: $ 91.03
# Sell: $ 91.03 | Profit: $ 0.00
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 97.00
# 1/1 [==============================] - 0s 19ms/step
# Sell: $ 97.27 | Profit: $ 0.27
# 1/1 [==============================] - 0s 16ms/step
# Buy: $ 92.61
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 94.81 | Profit: $ 2.19
# Buy: $ 93.25
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 95.04 | Profit: $ 1.79
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 113.01
# Buy: $ 114.91
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 114.61 | Profit: $ 1.60
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 115.56 | Profit: $ 0.65
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 120.88
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 112.82 | Profit: -$ 8.06
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 112.00
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 115.36 | Profit: $ 3.36
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 110.34
# Buy: $ 106.84
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 110.08 | Profit: -$ 0.26
# Buy: $ 111.81
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 107.12 | Profit: $ 0.28
# 1/1 [==============================] - 0s 16ms/step
# Buy: $ 108.22
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 112.28 | Profit: $ 0.47
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 114.96 | Profit: $ 6.74
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 115.81
# Sell: $ 116.79 | Profit: $ 0.98
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 115.08
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 114.97 | Profit: -$ 0.11
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 116.97
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 124.40 | Profit: $ 7.43
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 121.10
# 1/1 [==============================] - 0s 16ms/step
# Buy: $ 121.19
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 120.71 | Profit: -$ 0.39
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 119.02
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 117.51 | Profit: -$ 3.68
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 116.87 | Profit: -$ 2.15
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 115.04
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 115.05
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 116.60 | Profit: $ 1.56
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 111.20 | Profit: -$ 3.85
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 115.32
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 108.86 | Profit: -$ 6.46
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 108.77
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 110.44 | Profit: $ 1.67
# Buy: $ 119.03
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 118.69 | Profit: -$ 0.34
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 116.32
# Sell: $ 115.97 | Profit: -$ 0.35
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 113.85
# Buy: $ 115.17
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 116.03 | Profit: $ 2.18
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 116.59 | Profit: $ 1.42
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 126.66
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 131.88 | Profit: $ 5.22
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 131.97
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 136.69 | Profit: $ 4.72
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 133.72
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 129.41 | Profit: -$ 4.31
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 130.92
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 128.98
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 128.80
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 130.89 | Profit: -$ 0.03
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 128.91 | Profit: -$ 0.07
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 127.14
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 127.83
# 1/1 [==============================] - 0s 26ms/step
# Sell: $ 132.03 | Profit: $ 3.23
# 1/1 [==============================] - 0s 17ms/step
# Sell: $ 136.87 | Profit: $ 9.73
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 139.07 | Profit: $ 11.24
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 142.06
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 134.14 | Profit: -$ 7.92
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 135.39
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 135.13 | Profit: -$ 0.26
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 129.71
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 129.87 | Profit: $ 0.16
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 125.86
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 125.35 | Profit: -$ 0.51
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 120.99
# Sell: $ 121.26 | Profit: $ 0.27
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 122.06
# 1/1 [==============================] - 0s 16ms/step
# Buy: $ 120.13
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 121.42 | Profit: -$ 0.64
# 1/1 [==============================] - 0s 17ms/step
# Sell: $ 116.36 | Profit: -$ 3.77
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 121.96
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 121.03 | Profit: -$ 0.93
# 1/1 [==============================] - 0s 16ms/step
# Buy: $ 123.99
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 125.57 | Profit: $ 1.58
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 124.76
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 119.99
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 123.39 | Profit: -$ 1.37
# Sell: $ 122.54 | Profit: $ 2.55
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 120.59
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 121.21 | Profit: $ 0.62
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 119.90
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 122.15
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 123.00 | Profit: $ 3.10
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 125.90 | Profit: $ 3.75
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 134.43
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 134.50
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 134.16 | Profit: -$ 0.27
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 134.84
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 133.11 | Profit: -$ 1.39
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 133.50
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 131.94 | Profit: -$ 2.90
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 134.39 | Profit: $ 0.89
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 133.48
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 132.54
# Sell: $ 127.85 | Profit: -$ 5.63
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 128.10
# 1/1 [==============================] - 0s 20ms/step
# Sell: $ 129.74 | Profit: -$ 2.80
# Buy: $ 130.21
# 1/1 [==============================] - 0s 27ms/step
# Sell: $ 126.85 | Profit: -$ 1.25
# 1/1 [==============================] - 0s 16ms/step
# Buy: $ 125.91
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 127.45 | Profit: -$ 2.76
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 126.27 | Profit: $ 0.36
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 124.85
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 127.31 | Profit: $ 2.46
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 127.10
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 126.90 | Profit: -$ 0.20
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 126.85
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 124.61
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 125.06 | Profit: -$ 1.79
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 123.54 | Profit: -$ 1.07
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 125.89
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 125.90 | Profit: $ 0.01
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 126.74
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 127.13 | Profit: $ 0.39
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 126.11
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 127.35 | Profit: $ 1.24
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 130.15
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 131.79 | Profit: $ 1.64
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 133.11
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 134.78 | Profit: $ 1.67
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 145.11
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 144.50 | Profit: -$ 0.61
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 145.64
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 149.15 | Profit: $ 3.51
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 146.09
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 145.60 | Profit: -$ 0.49
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 146.36
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 148.19 | Profit: $ 1.83
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 148.36
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 148.60
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 153.12 | Profit: $ 4.76
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 151.83 | Profit: $ 3.23
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 152.51
# Sell: $ 153.65 | Profit: $ 1.14
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 155.11
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 154.07
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 149.55
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 148.12 | Profit: -$ 6.99
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 149.03 | Profit: -$ 5.04
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 148.79 | Profit: -$ 0.76
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 146.06
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 143.43
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 145.85 | Profit: -$ 0.21
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 146.83 | Profit: $ 3.40
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 145.37
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 141.50 | Profit: -$ 3.87
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 141.11
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 142.00 | Profit: $ 0.89
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# Buy: $ 142.81
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 143.76 | Profit: $ 0.95
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 148.96
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 150.02 | Profit: $ 1.06
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 147.87
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 149.99 | Profit: $ 2.12
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 163.76
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 161.84
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 165.32 | Profit: $ 1.56
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 171.18 | Profit: $ 9.34
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 171.14
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 169.75
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 172.99
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 175.64 | Profit: $ 4.50
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 176.28 | Profit: $ 6.53
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 180.33 | Profit: $ 7.34
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 179.38
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 177.57
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 182.01 | Profit: $ 2.63
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 179.70 | Profit: $ 2.13
# 1/1 [==============================] - 0s 16ms/step
# Buy: $ 174.92
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 172.17
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 172.19 | Profit: -$ 2.73
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 175.08 | Profit: $ 2.91
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 172.19
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 173.07
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 166.23
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 162.41
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 161.62 | Profit: -$ 10.57
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 159.78 | Profit: -$ 13.29
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 159.69 | Profit: -$ 6.54
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 159.22 | Profit: -$ 3.19
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 172.12
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 168.88
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 172.79 | Profit: $ 0.67
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 172.55 | Profit: $ 3.67
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 168.88
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 167.30
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 160.07
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 162.74 | Profit: -$ 6.14
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 164.85 | Profit: -$ 2.45
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 165.12 | Profit: $ 5.05
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 166.56
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 166.23 | Profit: -$ 0.33
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 163.17
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 157.44
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 162.95 | Profit: -$ 0.22
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 158.52 | Profit: $ 1.08
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 154.73
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 150.62
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 155.09
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 159.59 | Profit: $ 4.86
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 160.62 | Profit: $ 10.00
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 163.98 | Profit: $ 8.89
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 171.83
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 172.14
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 170.09
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 165.75
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 167.66 | Profit: -$ 4.17
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 170.40 | Profit: -$ 1.74
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 165.29 | Profit: -$ 4.80
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 165.07
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 167.40 | Profit: $ 1.65
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 167.23 | Profit: $ 2.16
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 161.79
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 162.88
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 156.80 | Profit: -$ 4.99
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 156.57
# Buy: $ 163.64
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 157.65 | Profit: -$ 5.23
# Sell: $ 157.96 | Profit: $ 1.39
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 159.48 | Profit: -$ 4.16
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 157.28
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 154.51
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 146.50 | Profit: -$ 10.78
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 142.56
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 147.11 | Profit: -$ 7.40
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 145.54
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 149.24 | Profit: $ 6.68
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 140.82
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 137.35
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 143.11 | Profit: -$ 2.43
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 140.36 | Profit: -$ 0.46
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 140.52
# Sell: $ 143.78 | Profit: $ 6.43
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 149.64 | Profit: $ 9.12
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 148.71
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# Buy: $ 146.14
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 148.71 | Profit: $ 0.00
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 147.96
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 132.76 | Profit: -$ 13.38
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 135.43 | Profit: -$ 12.53
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 131.56
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 135.87 | Profit: $ 4.31
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 135.35
# Sell: $ 138.27 | Profit: $ 2.92
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 139.23
# Buy: $ 136.72
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 138.93
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 141.56 | Profit: $ 2.33
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 142.92 | Profit: $ 6.20
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 147.04 | Profit: $ 8.11
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 147.07
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 153.04 | Profit: $ 5.97
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 165.35
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 164.87
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 164.92
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 169.24 | Profit: $ 3.89
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 168.49 | Profit: $ 3.62
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 172.10 | Profit: $ 7.18
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 173.03
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 174.55 | Profit: $ 1.52
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 167.23
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 167.53 | Profit: $ 0.30
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 161.38
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 157.22 | Profit: -$ 4.16
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 154.53
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 155.96 | Profit: $ 1.43
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 153.84
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 155.31 | Profit: $ 1.47
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 150.70
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 154.48 | Profit: $ 3.78
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 152.74
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 150.77
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 151.76 | Profit: -$ 0.98
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 149.84 | Profit: -$ 0.93
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 142.48
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 138.20
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 142.45
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 146.10 | Profit: $ 3.62
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 146.40 | Profit: $ 8.20
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 145.43
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 138.34
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 142.99 | Profit: $ 0.54
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 138.38 | Profit: -$ 7.05
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 142.41 | Profit: $ 4.07
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 143.86
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 147.27
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 149.45 | Profit: $ 5.59
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 152.34 | Profit: $ 5.07
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 150.65
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 145.03
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 138.88
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 138.38
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 138.92 | Profit: -$ 11.73
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 139.50 | Profit: -$ 5.53
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 134.87
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 146.87
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 149.70 | Profit: $ 10.82
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 148.28
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 150.04
# 1/1 [==============================] - 0s 16ms/step
# Buy: $ 148.79
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 150.72
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 151.29 | Profit: $ 12.91
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 148.01
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 151.07 | Profit: $ 16.20
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 148.11
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 141.17
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 148.03
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 148.31 | Profit: $ 1.44
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 147.81 | Profit: -$ 0.47
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 146.63
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 142.91
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# ...
# Buy: $ 157.96
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 159.48
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 156.77
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 152.06
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 154.51
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 146.50
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 142.56
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 147.11
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 145.54
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 149.24
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 140.82
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 137.35
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 137.59
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 143.11
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 140.36
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 140.52
# 1/1 [==============================] - 0s 16ms/step
# Buy: $ 143.78
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 149.64 | Profit: -$ 20.11
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 148.84 | Profit: -$ 24.15
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 148.71 | Profit: -$ 30.58
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 145.38 | Profit: -$ 32.82
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 146.14
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 148.71
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 142.64
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 137.13
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 131.88
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 132.76
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 135.43 | Profit: -$ 42.14
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 130.06
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 135.87
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 141.66 | Profit: -$ 38.04
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 141.66 | Profit: -$ 33.26
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 137.44
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 136.72
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 138.93
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 141.56 | Profit: -$ 30.44
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 142.92 | Profit: -$ 29.25
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 146.35 | Profit: -$ 25.84
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 147.04 | Profit: -$ 25.15
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 144.87 | Profit: -$ 24.93
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 145.86 | Profit: -$ 20.37
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 145.49
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 148.47 | Profit: -$ 16.04
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 150.17 | Profit: -$ 12.24
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 147.07 | Profit: -$ 14.55
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 151.00 | Profit: -$ 8.78
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 153.04
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 155.35 | Profit: -$ 4.34
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 154.09 | Profit: -$ 5.13
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 152.95
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 151.60
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 156.79 | Profit: -$ 16.11
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 157.35 | Profit: -$ 15.04
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 162.51 | Profit: -$ 9.15
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 161.51 | Profit: -$ 10.61
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 160.01
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 166.13 | Profit: -$ 2.51
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 165.81
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 165.35
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 164.87
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 164.92
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 169.24 | Profit: $ 0.36
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 168.49 | Profit: -$ 0.39
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 172.10 | Profit: $ 4.80
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 173.19 | Profit: $ 8.87
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 174.55 | Profit: $ 14.48
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 174.15
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 171.52
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 167.57
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 167.23
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 167.53
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 170.03 | Profit: $ 7.29
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 163.62
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 161.38
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 158.91
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 157.22
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 157.96
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 155.81
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 154.53
# 1/1 [==============================] - 0s 19ms/step
# Buy: $ 155.96
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 154.46
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 157.37
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 163.43 | Profit: $ 0.23
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 153.84
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 155.31
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 152.37
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 150.70
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 154.48
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 156.90
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 153.72
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 152.74
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 150.43
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 150.77
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 151.76 | Profit: -$ 14.47
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 149.84
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 142.48
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 138.20
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 142.45
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 146.10 | Profit: -$ 17.07
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 146.40 | Profit: -$ 12.90
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 140.09
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 140.42
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 138.98
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 138.34
# 1/1 [==============================] - 0s 16ms/step
# Buy: $ 142.99
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 138.38
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 147.27 | Profit: -$ 10.17
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 149.45 | Profit: -$ 13.50
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 152.34 | Profit: -$ 6.18
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 149.35 | Profit: -$ 5.38
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 144.80
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 153.34
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 150.65
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 145.03
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 138.88
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 138.38
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 138.92
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 139.50 | Profit: -$ 11.12
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 134.87
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 146.87 | Profit: -$ 8.22
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 148.79
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 148.01
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 151.07
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 148.11
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 144.22
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 141.17
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 148.03
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 148.31 | Profit: -$ 26.30
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 147.81
# 1/1 [==============================] - 0s 16ms/step
# Buy: $ 146.63
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 142.91
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 140.94
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 142.65
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 142.16
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 136.50
# 1/1 [==============================] - 0s 18ms/step
# Buy: $ 134.51
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 132.37
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 132.30
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 135.45 | Profit: -$ 38.86
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 132.23
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 131.86
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 130.03
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 126.04
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 129.61
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 129.93
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 125.07
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 126.36
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 125.02
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 130.15
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 130.73 | Profit: -$ 44.33
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 133.49 | Profit: -$ 38.34
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 133.41 | Profit: -$ 38.73
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 134.76 | Profit: -$ 35.33
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 135.94 | Profit: -$ 29.81
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 135.21 | Profit: -$ 32.45
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 137.87 | Profit: -$ 32.53
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 141.11 | Profit: -$ 24.18
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 142.53 | Profit: -$ 22.54
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 141.86 | Profit: -$ 25.54
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 143.96 | Profit: -$ 22.46
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 145.93 | Profit: -$ 15.86
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# Buy: $ 145.43
# 1/1 [==============================] - 0s 21ms/step
# Sell: $ 150.82 | Profit: -$ 12.06
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 154.50 | Profit: -$ 2.30
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 151.73 | Profit: -$ 4.84
# 1/1 [==============================] - 0s 15ms/step
# Sell: $ 154.65 | Profit: -$ 8.99
# 1/1 [==============================] - 0s 14ms/step
# Buy: $ 151.92
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 150.87
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 151.01
# 1/1 [==============================] - 0s 16ms/step
# Sell: $ 153.85 | Profit: -$ 3.80
# 1/1 [==============================] - 0s 14ms/step
# Sell: $ 153.20 | Profit: -$ 4.76
# 1/1 [==============================] - 0s 13ms/step
# Sell: $ 155.33 | Profit: -$ 4.15
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 153.71
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 152.55
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 148.48
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 148.91
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 149.40
# 1/1 [==============================] - 0s 15ms/step
# Buy: $ 146.71
# 1/1 [==============================] - 0s 13ms/step
# Buy: $ 147.92
# --------------------------------
# Total Profit: $ 1204.45
# --------------------------------
# INFO:tensorflow:Assets written to: 20/assets
# INFO:tensorflow:Assets written to: 20/assets
#     Episode  Total_Buy_Actions  Total_Sell_Actions  Total_profit
# 0         0                265                 263     90.509941
# 1         1                351                 298    314.897419
# 2         2                369                 331    747.777588
# 3         3                214                 207    937.700104
# 4         4                396                 344    798.510044
# 5         5                297                 234   1026.267540
# 6         6                444                 364    929.035152
# 7         7                414                 328   1034.402569
# 8         8                292                 229    654.602619
# 9         9                299                 245    706.987583
# 10       10                241                 173    346.902550
# 11       11                235                 173    319.167580
# 12       12                283                 244   1100.167610
# 13       13                382                 271   2055.522530
# 14       14                468                 351   2036.502594
# 15       15                473                 352   1798.675091
# 16       16                410                 283   1578.240097
# 17       17                534                 385   2339.542557
# 18       18                439                 295   1379.917580
# 19       19                480                 432   3854.262508
# 20       20                389                 273   1204.450115

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.savefig('training_scores.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# Run a stock trading simulation using a pre-trained Deep Q-Network (DQN) model.

# Model Loading:
  # Takes a user input (int) for the model name.
  # Loads a pre-trained model saved during training part based on the provided name.
model_name = input()
model = load_model(model_name)

# Extracts the window size from the input shape of the first layer of the model,
# which indicates how many past time steps (e.g., days of stock prices) the model expects as input.
window_size = model.layers[0].input.shape.as_list()[1]

# Initialize an agent for evaluation (True parameter indicates evaluation mode),
# with the window size derived from the model and the name of the model.
agent = Agent(window_size, True, model_name)

# Initialize data, batch_size, initial state, initial profit, and inventory (similar as training part).
data=list(price_df['Close'][1000:])
data_df = pd.DataFrame(data, columns=['Close'])

l = len(data) - 1
batch_size = 32
state = getState(data, 0, window_size + 1)
total_profit = 0
action_list = []
agent.inventory = []

# Similar work as in the training process, except that there is no model training step:
for t in range(l):
    action = agent.act(state)
    print(action)
    # sit
    next_state = getState(data, t + 1, window_size + 1)
    reward = 0
    if action == 1: # buy
        agent.inventory.append(data[t])
        action_list.append(action)
        print("Buy: " + formatPrice(data[t]))

    elif action == 2 and len(agent.inventory) > 0: # sell
        bought_price = agent.inventory.pop(0)
        reward = max(data[t] - bought_price, 0)
        total_profit += data[t] - bought_price
        action_list.append(action)
        print("Sell: " + formatPrice(data[t]) + " | Profit: " + formatPrice(data[t] - bought_price))

    else:
        action_list.append(0)
    done = True if t == l - 1 else False
    agent.memory.append((state, action, reward, next_state, done))
    state = next_state

    if done:
        print("--------------------------------")
        print(ticker + " Total Profit: " + formatPrice(total_profit))
        action_list.append(0)
        data_df['action'] = action_list
        data_df["Close"].plot(figsize=(8, 5), grid=True)
        sell_signals = data_df[data_df['action'] == 2]
        buy_signals = data_df[data_df['action'] == 1]

        plt.scatter(sell_signals.index, sell_signals["Close"], c='r', marker='v', label='Sell')
        plt.scatter(buy_signals.index, buy_signals["Close"], c='g', marker='^', label='Buy')

        plt.legend(['value', 'sell', 'buy'])
        plt.title('total profit %f'%(total_profit))
        plt.savefig('evaluating_graph.png')
        plt.show()

    # Notice that there are several main differences between evaluation process and training process before:
    # 1. Exploitation Only: The agent exclusively uses its learned policy to make decisions, without random exploration.
    # 2. No Model Updates: The agent does not update its model during evaluation. Experiences may still be stored (for review or analysis),
    # but they are not used for training. The focus is on assessing the effectiveness of the current policy.
    # 3. Consistent Policy: Since the model is not being updated, the agent's policy remains consistent throughout the evaluation phase.
# Out:
# 1/1 [==============================] - 0s 37ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 2
# 1/1 [==============================] - 0s 10ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 10ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 11ms/step
# 0
# 1/1 [==============================] - 0s 12ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 11ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 1
# Buy: $ 160.77
# 1/1 [==============================] - 0s 10ms/step
# 2
# Sell: $ 162.36 | Profit: $ 1.59
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 10ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 11ms/step
# 0
# 1/1 [==============================] - 0s 12ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 160.80
# 1/1 [==============================] - 0s 10ms/step
# 1
# Buy: $ 160.10
# 1/1 [==============================] - 0s 10ms/step
# 1
# Buy: $ 165.56
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 165.21 | Profit: $ 4.41
# 1/1 [==============================] - 0s 10ms/step
# 2
# Sell: $ 165.23 | Profit: $ 5.13
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 166.47 | Profit: $ 0.91
# 1/1 [==============================] - 0s 10ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 163.76
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 168.41 | Profit: $ 4.65
# 1/1 [==============================] - 0s 10ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 171.77
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 173.56 | Profit: $ 1.79
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 173.75
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 20ms/step
# 1
# Buy: $ 172.07
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 172.69 | Profit: -$ 1.06
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 175.05 | Profit: $ 2.98
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 10ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 180.57
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 180.96 | Profit: $ 0.39
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 8ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 183.95
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 186.01 | Profit: $ 2.06
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 187.00
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 186.68 | Profit: -$ 0.32
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 185.27
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 188.06 | Profit: $ 2.79
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 188.08
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 189.77
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 190.54 | Profit: $ 2.46
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 190.69 | Profit: $ 0.92
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 8ms/step
# 0
# 1/1 [==============================] - 0s 17ms/step
# 2
# 1/1 [==============================] - 0s 10ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 195.83
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 196.45 | Profit: $ 0.62
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 195.61
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 178.85
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 179.80
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 178.19 | Profit: -$ 17.42
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 177.97
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 177.79 | Profit: -$ 1.06
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 179.46
# 1/1 [==============================] - 0s 10ms/step
# 2
# Sell: $ 177.45 | Profit: -$ 2.35
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 176.57
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 1
# Buy: $ 174.49
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 175.84 | Profit: -$ 2.13
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 177.23 | Profit: -$ 2.23
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 181.12 | Profit: $ 4.55
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 180.19 | Profit: $ 5.70
# 1/1 [==============================] - 0s 13ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 10ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 174.21
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 175.74
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 175.01
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 177.97 | Profit: $ 3.76
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 179.07 | Profit: $ 3.33
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 175.49
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 174.79
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 176.08 | Profit: $ 1.07
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 171.96
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 170.43
# 1/1 [==============================] - 0s 12ms/step
# 1
# Buy: $ 170.69
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 171.21
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 173.75 | Profit: -$ 1.74
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 172.40 | Profit: -$ 2.39
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 173.66
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 174.91 | Profit: $ 2.95
# 1/1 [==============================] - 0s 15ms/step
# 2
# Sell: $ 177.49 | Profit: $ 7.06
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 178.99 | Profit: $ 8.30
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 8ms/step
# 1
# Buy: $ 172.88
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 173.00
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 173.44 | Profit: $ 2.23
# 1/1 [==============================] - 0s 10ms/step
# 1
# Buy: $ 171.10
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 168.22
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 170.29 | Profit: -$ 3.37
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 170.77 | Profit: -$ 2.11
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 173.97 | Profit: $ 0.97
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 177.57 | Profit: $ 6.47
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 181.82 | Profit: $ 13.60
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 15ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 1
# Buy: $ 186.40
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 188.01 | Profit: $ 1.61
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 189.71
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 189.69 | Profit: -$ 0.02
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 191.45
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 1
# Buy: $ 189.79
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 190.40 | Profit: -$ 1.05
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 189.37
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 189.95
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 191.24 | Profit: $ 1.45
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 189.43
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 193.42 | Profit: $ 4.05
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 192.32 | Profit: $ 2.37
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 194.27
# 1/1 [==============================] - 0s 8ms/step
# 2
# Sell: $ 195.71 | Profit: $ 6.28
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 193.18
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 14ms/step
# 2
# Sell: $ 197.96 | Profit: $ 3.69
# 1/1 [==============================] - 0s 10ms/step
# 2
# Sell: $ 198.11 | Profit: $ 4.93
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 194.68
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 193.05
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 193.15 | Profit: -$ 1.53
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 193.58 | Profit: $ 0.53
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 181.18
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 185.56 | Profit: $ 4.38
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 8ms/step
# 1
# Buy: $ 185.59
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 185.92
# 1/1 [==============================] - 0s 19ms/step
# 0
# 1/1 [==============================] - 0s 11ms/step
# 0
# 1/1 [==============================] - 0s 8ms/step
# 2
# Sell: $ 188.63 | Profit: $ 3.04
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 191.56 | Profit: $ 5.64
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 1
# Buy: $ 184.40
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 186.86 | Profit: $ 2.46
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 8ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 2
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 25ms/step
# 0
# 1/1 [==============================] - 0s 10ms/step
# 1
# Buy: $ 183.86
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 182.31
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 181.56
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 182.32 | Profit: -$ 1.54
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 184.37 | Profit: $ 2.06
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 182.52 | Profit: $ 0.96
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 181.16
# 1/1 [==============================] - 0s 10ms/step
# 1
# Buy: $ 182.63
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 180.75
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 179.66
# 1/1 [==============================] - 0s 10ms/step
# 1
# Buy: $ 175.10
# 1/1 [==============================] - 0s 9ms/step
# 0
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 169.12
# 1/1 [==============================] - 0s 9ms/step
# 1
# Buy: $ 169.00
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 170.73 | Profit: -$ 10.43
# 1/1 [==============================] - 0s 9ms/step
# 2
# Sell: $ 172.75 | Profit: -$ 9.88
# --------------------------------
# AAPL Total Profit: $ 73.51
